# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

import requests 
from bs4 import BeautifulSoup

# %%
df = pd.DataFrame({"player":player,
                   "matches":mat,
                   "inns":inns,
                   "not_out":not_out,
                   "runs":runs,
                   "high_score":high_score,
                   "avg":avg,
                   "balls_faced":balls_faced,
                   "strike_rate":strike_rate,
                   "century":century,
                   "half_century":half_cen,
                   "four":four,
                   "six":six,
                   "season":season
                     })
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29724/4004164798.py in <module>
# ----> 1 df = pd.DataFrame({"player":player,
#       2                    "matches":mat,
#       3                    "inns":inns,
#       4                    "not_out":not_out,
#       5                    "runs":runs,
#
# NameError: name 'player' is not defined

# %%
df.to_csv("rrrdataipl.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29724/3310631017.py in <module>
# ----> 1 df.to_csv("rrrdataipl.csv")
#
# NameError: name 'df' is not defined

# %%
df = pd.read_csv("rrrdataipl.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1           player  matches  inns  \
# 0           0             0               0      Chris Gayle       15    14
# 1           1             1               1   Gautam Gambhir       17    17
# 2           2             2               2   Shikhar Dhawan       15    15
# 3           3             3               3   Ajinkya Rahane       16    16
# 4           4             4               4  Virender Sehwag       16    16
#
#    not_out  runs high_score    avg  balls_faced  strike_rate  century  \
# 0        2   733       128*  61.08          456       160.74        1
# 1        2   590         93  39.33          411       143.55        0
# 2        1   569         84  40.64          439       129.61        0
# 3        2   560       103*  40.00          433       129.33        1
# 4        1   495        87*  33.00          307       161.23        0
#
#    half_century  four  six  season
# 0             7    46   59    2012
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1255 entries, 0 to 1254
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      1255 non-null   int64
#  1   Unnamed: 0.1    1255 non-null   int64
#  2   Unnamed: 0.1.1  1255 non-null   int64
#  3   player          1255 non-null   object
#  4   matches         1255 non-null   int64
#  5   inns            1255 non-null   int64
#  6   not_out         1255 non-null   int64
#  7   runs            1255 non-null   int64
#  8   high_score      1255 non-null   object
#  9   avg             1255 non-null   float64
#  10  balls_faced     1255 non-null   int64
#  11  strike_rate     1255 non-null   float64
#  12  century         1255 non-null   int64
#  13  half_century    1255 non-null   int64
#  14  four            1255 non-null   int64
#  15  six             1255 non-null   int64
#  16  season          1255 non-null   int64
# ...

# %%
df.shape
# Out:
# (1255, 17)

# %%
df['high_score']=df['high_score'].apply(lambda x: x.replace('*',''))

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1           player  matches  inns  \
# 0           0             0               0      Chris Gayle       15    14
# 1           1             1               1   Gautam Gambhir       17    17
# 2           2             2               2   Shikhar Dhawan       15    15
# 3           3             3               3   Ajinkya Rahane       16    16
# 4           4             4               4  Virender Sehwag       16    16
#
#    not_out  runs high_score    avg  balls_faced  strike_rate  century  \
# 0        2   733        128  61.08          456       160.74        1
# 1        2   590         93  39.33          411       143.55        0
# 2        1   569         84  40.64          439       129.61        0
# 3        2   560        103  40.00          433       129.33        1
# 4        1   495         87  33.00          307       161.23        0
#
#    half_century  four  six  season
# 0             7    46   59    2012
# ...

# %%
df=df.loc[df.inns>10,:]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351 entries, 0 to 1177
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      351 non-null    int64
#  1   Unnamed: 0.1    351 non-null    int64
#  2   Unnamed: 0.1.1  351 non-null    int64
#  3   player          351 non-null    object
#  4   matches         351 non-null    int64
#  5   inns            351 non-null    int64
#  6   not_out         351 non-null    int64
#  7   runs            351 non-null    int64
#  8   high_score      351 non-null    object
#  9   avg             351 non-null    float64
#  10  balls_faced     351 non-null    int64
#  11  strike_rate     351 non-null    float64
#  12  century         351 non-null    int64
#  13  half_century    351 non-null    int64
#  14  four            351 non-null    int64
#  15  six             351 non-null    int64
#  16  season          351 non-null    int64
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1           player  matches  \
# 1163        1163          1163            1163  Shimron Hetmyer       12
# 1164        1164          1164            1164   Dinesh Karthik       14
# 1165        1165          1165            1165      Pat Cummins       14
# 1176        1176          1176            1176    Krunal Pandya       16
# 1177        1177          1177            1177    Glenn Maxwell       13
#
#       inns  not_out  runs high_score    avg  balls_faced  strike_rate  \
# 1163    11        3   185         45  23.12          125       148.00
# 1164    14        2   169         58  14.08          134       126.11
# 1165    11        4   146         53  20.85          114       128.07
# 1176    12        6   109         34  18.16           92       118.47
# 1177    11        4   108         32  15.42          106       101.88
#
#       century  half_century  four  six  season
# 1163        0             0    11   12    2020
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.drop(['Unnamed: 0.1'], axis=1, inplace=True)

# %%
df.drop(['Unnamed: 0.1.1'], axis=1, inplace=True)

# %%
df.columnsdf=df.loc[df.inns>10,:]
# Out:
# Index(['player', 'matches', 'inns', 'not_out', 'runs', 'high_score', 'avg',
#        'balls_faced', 'strike_rate', 'century', 'half_century', 'four', 'six',
#        'season'],
#       dtype='object')

# %%
df.head()
# Out:
#             player  matches  inns  not_out  runs high_score    avg  \
# 0      Chris Gayle       15    14        2   733        128  61.08
# 1   Gautam Gambhir       17    17        2   590         93  39.33
# 2   Shikhar Dhawan       15    15        1   569         84  40.64
# 3   Ajinkya Rahane       16    16        2   560        103  40.00
# 4  Virender Sehwag       16    16        1   495         87  33.00
#
#    balls_faced  strike_rate  century  half_century  four  six  season
# 0          456       160.74        1             7    46   59    2012
# 1          411       143.55        0             6    64   17    2012
# 2          439       129.61        0             5    58   18    2012
# 3          433       129.33        1             3    73   10    2012
# 4          307       161.23        0             5    57   19    2012

# %%
display(df.dtypes)
# Out:
# player           object
# matches           int64
# inns              int64
# not_out           int64
# runs              int64
# high_score       object
# avg             float64
# balls_faced       int64
# strike_rate     float64
# century           int64
# half_century      int64
# four              int64
# six               int64
# season            int64
# dtype: object

# %%
df.astype({'avg':'int','strike_rate':'int','high_score':'int'})
# Out:
#                player  matches  inns  not_out  runs  high_score  avg  \
# 0         Chris Gayle       15    14        2   733         128   61
# 1      Gautam Gambhir       17    17        2   590          93   39
# 2      Shikhar Dhawan       15    15        1   569          84   40
# 3      Ajinkya Rahane       16    16        2   560         103   40
# 4     Virender Sehwag       16    16        1   495          87   33
# ...               ...      ...   ...      ...   ...         ...  ...
# 1163  Shimron Hetmyer       12    11        3   185          45   23
# 1164   Dinesh Karthik       14    14        2   169          58   14
# 1165      Pat Cummins       14    11        4   146          53   20
# 1176    Krunal Pandya       16    12        6   109          34   18
# 1177    Glenn Maxwell       13    11        4   108          32   15
#
#       balls_faced  strike_rate  century  half_century  four  six  season
# ...

# %%
display(df.dtypes)
# Out:
# player           object
# matches           int64
# inns              int64
# not_out           int64
# runs              int64
# high_score       object
# avg             float64
# balls_faced       int64
# strike_rate     float64
# century           int64
# half_century      int64
# four              int64
# six               int64
# season            int64
# dtype: object

# %%
df.astype({'strike_rate':'int'})
# Out:
#                player  matches  inns  not_out  runs high_score    avg  \
# 0         Chris Gayle       15    14        2   733        128  61.08
# 1      Gautam Gambhir       17    17        2   590         93  39.33
# 2      Shikhar Dhawan       15    15        1   569         84  40.64
# 3      Ajinkya Rahane       16    16        2   560        103  40.00
# 4     Virender Sehwag       16    16        1   495         87  33.00
# ...               ...      ...   ...      ...   ...        ...    ...
# 1163  Shimron Hetmyer       12    11        3   185         45  23.12
# 1164   Dinesh Karthik       14    14        2   169         58  14.08
# 1165      Pat Cummins       14    11        4   146         53  20.85
# 1176    Krunal Pandya       16    12        6   109         34  18.16
# 1177    Glenn Maxwell       13    11        4   108         32  15.42
#
#       balls_faced  strike_rate  century  half_century  four  six  season
# ...

# %%
display(df.dtypes)
# Out:
# player           object
# matches           int64
# inns              int64
# not_out           int64
# runs              int64
# high_score       object
# avg             float64
# balls_faced       int64
# strike_rate     float64
# century           int64
# half_century      int64
# four              int64
# six               int64
# season            int64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df.loc[df.inns>10,:]

# %%
plt.figure(figsize =(7,5))
sns.countplot(x=df['century'])
# Out:
# <AxesSubplot:xlabel='century', ylabel='count'>

# %%
plt.figure(figsize =(7,5))
sns.countplot(x=df['half_century'].nlargest(20))
# Out:
# <AxesSubplot:xlabel='half_century', ylabel='count'>

# %%
plt.figure(figsize =(10,5))
sns.countplot(x=df['high_score'].max())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29724/2210559443.py in <module>
#       1 plt.figure(figsize =(10,5))
# ----> 2 sns.countplot(x=df['high_score'].max())
#
# ~\Downloads\h\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Downloads\h\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3596         raise ValueError("Cannot pass values for both `x` and `y`")
#    3597
# -> 3598     plotter = _CountPlotter(
#    3599         x, y, hue, data, order, hue_order,
#    3600         estimator, ci, n_boot, units, seed,
#
# ...

# %%
plt.figure(figsize =(5,5))
sns.countplot(x=df['not_out'])
# Out:
# <AxesSubplot:xlabel='not_out', ylabel='count'>

# %%
plt.figure(figsize =(5,5))
sns.countplot(x=df['six'].nlargest(60))
# Out:
# <AxesSubplot:xlabel='six', ylabel='count'>

# %%
sns.histplot(x=df['four'])
# Out:
# <AxesSubplot:xlabel='four', ylabel='Count'>

# %%
plt.figure(figsize =(5,5))
sns.displot(x= df['four'],kind = 'hist')

# %%
sns.histplot(x=df['avg'])
# Out:
# <AxesSubplot:xlabel='avg', ylabel='Count'>

# %%
sns.histplot(x=df['not_out'])
# Out:
# <AxesSubplot:xlabel='not_out', ylabel='Count'>

# %%
sns.histplot(x=df['six'])
# Out:
# <AxesSubplot:xlabel='six', ylabel='Count'>

# %%
## dis
sns.histplot(df["high_score"])
# Out:
# <AxesSubplot:xlabel='high_score', ylabel='Count'>

# %%
#HIGH SCORE FOR ALL SEASON SCORED FOR ALL SEASONS ONLY TOP TEN
# scORE WAS HIGHEST DURING 2013 with 17
sns.distplot(x=df['high_score'])
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(x=df['runs'])
# Out:
# <AxesSubplot:xlabel='runs', ylabel='Count'>

# %%
sns.histplot(x=df['strike_rate'])
# Out:
# <AxesSubplot:xlabel='strike_rate', ylabel='Count'>

# %%
sns.histplot(x=df['balls_faced'])
# Out:
# <AxesSubplot:xlabel='balls_faced', ylabel='Count'>

# %%
#BI VARIATE ANALYSIS

# %%
#total runs per season vs runs ipl 2013-2020
  #MOST RUNS WAS SCORED DURING THE SEASONS OF 2013, 2016 ,2018
  #LEAST RUNS WAS  SCORED THE 2017 SEASON
plt.figure(figsize =(5,5))
sns.boxplot(x= df["season"]  ,    y=  df["runs"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
plt.figure(figsize =(5,5))
sns.boxplot(x= df["season"]  ,    y=  df["six"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='six'>

# %%
plt.figure(figsize =(5,5))
sns.boxplot(x= df["season"]  ,    y=  df["strike_rate"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='strike_rate'>

# %%
plt.figure(figsize =(5,5))
sns.boxplot(x= df["season"]  ,    y=  df["four"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='four'>

# %%
#MOST RUNS SCORED BY THE BATSMEN FROM ALL SEASON ONLY TOP TEN
#VIRAT KOHLI SCORED THE HIGHEST RUNS AND DINESH KARTHIK AT THE BOTTOM TEN 

plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["runs"].sum().nlargest(10))

# %%
plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["strike_rate"].sum().nlargest(10))

# %%
plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["six"].sum().nlargest(10))

# %%
plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["four"].sum().nlargest(10))

# %%
plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["balls_faced"].sum().nlargest(10))

# %%
plt.figure(figsize=(13,3))
plt.plot(df.groupby("player")["not_out"].sum().nlargest(10))

# %%
plt.figure(figsize =(10,4))
sns.scatterplot(x=df['season'],y=df['runs'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
dfr=df.loc[df.avg>30,:]

# %%
plt.figure(figsize =(5,5))
sns.boxplot(x= dfr["season"]  , y=  dfr["avg"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='avg'>

# %%
plt.figure(figsize =(5,5))
sns.barplot(x= dfr["season"]  ,    y=  dfr["avg"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='avg'>

# %%
plt.figure(figsize =(5,5))
sns.boxplot(x= df["season"]  ,    y=  df["runs"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
sns.boxplot(x= df["season"]  ,    y=  df["runs"])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
dfp=df.loc[df.runs>600,:]

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 0 to 1123
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player        16 non-null     object
#  1   matches       16 non-null     int64
#  2   inns          16 non-null     int64
#  3   not_out       16 non-null     int64
#  4   runs          16 non-null     int64
#  5   high_score    16 non-null     int64
#  6   avg           16 non-null     float64
#  7   balls_faced   16 non-null     int64
#  8   strike_rate   16 non-null     float64
#  9   century       16 non-null     int64
#  10  half_century  16 non-null     int64
#  11  four          16 non-null     int64
#  12  six           16 non-null     int64
#  13  season        16 non-null     int64
# dtypes: float64(2), int64(11), object(1)
# memory usage: 1.9+ KB

# %%
df.groupby("season")["runs"].max()
# Out:
# season
# 2012    733
# 2013    733
# 2014    660
# 2015    562
# 2016    973
# 2017    641
# 2018    735
# 2019    692
# 2020    670
# Name: runs, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.barplot(x= dfp["player"]  ,    y=  dfp["runs"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29724/3520151550.py in <module>
#       1 plt.figure(figsize=(10,10))
# ----> 2 sns.barplot(x= dfp["player"]  ,    y=  dfp["runs"])
#
# ~\Downloads\h\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Downloads\h\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3180 ):
#    3181
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
plt.figure(figsize=(15,10))
sns.barplot(x= dfp["player"]  ,    y=  dfp["six"])
# Out:
# <AxesSubplot:xlabel='player', ylabel='six'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x= dfp["player"]  ,    y=  dfp["four"])
# Out:
# <AxesSubplot:xlabel='player', ylabel='four'>

# %%
plt.figure(figsize=(15,10))
sns.barplot(x= dfp["player"]  ,    y=  dfp["runs"])

# %%
#

#SEASON VS RUNS USING STRIP PLOT WHO HAS MORE RUNS PER SEASON\

plt.figure(figsize =(5,5))
sns.stripplot(x=df['season'],  y= df['runs'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
df.describe()
# Out:
#          matches        inns     not_out        runs         avg  balls_faced  \
# count  351.00000  351.000000  351.000000  351.000000  351.000000   351.000000
# mean    14.57265   13.700855    2.470085  346.851852   31.339801   258.994302
# std      1.83295    1.874330    2.023742  140.446760   12.047362    98.138881
# min     11.00000   11.000000    0.000000   64.000000   10.280000    57.000000
# 25%     13.00000   12.000000    1.000000  246.500000   23.195000   184.000000
# 50%     14.00000   14.000000    2.000000  336.000000   29.430000   255.000000
# 75%     16.00000   15.000000    4.000000  432.500000   37.930000   319.000000
# max     19.00000   19.000000   10.000000  973.000000   83.200000   640.000000
#
#        strike_rate     century  half_century        four         six  \
# count   351.000000  351.000000    351.000000  351.000000  351.000000
# mean    133.999259    0.102564      2.102564   31.720798   13.455840
# ...

# %%
#MAX RUNS SCORED BY PLAYER PER SEASON TOP TEN
plt.figure(figsize =(5,5))
sns.barplot(x=df.groupby(["player"])["runs"].max().nlargest(10), data=df)
# Out:
# <AxesSubplot:xlabel='runs'>

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Downloads\h\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\Downloads\h\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'runs'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_29724/2828264808.py in <module>
#       1 plt.figure(figsize =(5,5))
# ...

# %%
df["player"]
# Out:
# 0           Chris Gayle
# 1        Gautam Gambhir
# 2        Shikhar Dhawan
# 3        Ajinkya Rahane
# 4       Virender Sehwag
#              ...
# 1163    Shimron Hetmyer
# 1164     Dinesh Karthik
# 1165        Pat Cummins
# 1176      Krunal Pandya
# 1177      Glenn Maxwell
# Name: player, Length: 351, dtype: object

# %%
highscores=df.groupby('season')['high_score']

# %%
highscores

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 351 entries, 0 to 1177
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   player        351 non-null    object
#  1   matches       351 non-null    int64
#  2   inns          351 non-null    int64
#  3   not_out       351 non-null    int64
#  4   runs          351 non-null    int64
#  5   high_score    351 non-null    object
#  6   avg           351 non-null    float64
#  7   balls_faced   351 non-null    int64
#  8   strike_rate   351 non-null    float64
#  9   century       351 non-null    int64
#  10  half_century  351 non-null    int64
#  11  four          351 non-null    int64
#  12  six           351 non-null    int64
#  13  season        351 non-null    int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 49.2+ KB

# %%
df['high_score']=pd.to_numeric(df['high_score'])

# %%
df1 = df.nlargest(10,'high_score')

# %%
 
#BATSMEN WITH HIGH_SCORE PER SEASON
plt.figure(figsize=(10,5))
sns.boxplot(df1['player'],df1['high_score'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df2 = df.groupby('player')['runs'].max()

# %%
df.season.unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020], dtype=int64)

# %%
 pd.to_datetime(df['season'],format='%Y').dt.year
# Out:
# 0       2012
# 1       2012
# 2       2012
# 3       2012
# 4       2012
#         ...
# 1163    2020
# 1164    2020
# 1165    2020
# 1176    2020
# 1177    2020
# Name: season, Length: 351, dtype: int64

# %%
#
plt.figure(figsize =(7,5))
sns.boxplot(x=df.groupby(["player"])["high_score"].max().nlargest(10), data=df)
# Out:
# <AxesSubplot:xlabel='high_score'>

# %%
df['runs']=pd.to_numeric(df['runs'])

# %%
runs=df.groupby('season')['runs']

# %%
df4= df.nlargest(10,'runs')

# %%
plt.figure(figsize=(10,5))
sns.barplot(df1['player'],df1['runs'],hue=df1['season'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(20,10))
sns.barplot(x=df['season'],  y= df['runs'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='runs'>

# %%
plt.figure(figsize=(12,7))
sns.barplot(df1['player'],df1['four'],hue=df1['season'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,7))
sns.barplot(df1['player'],df1['six'],hue=df1['season'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.barplot(df[df['avg']>40]['player'].head(),df[df['avg']>40]['avg'].head(),hue=df['season'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.lineplot(df1['player'],df1['four'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.lineplot(df1['player'],df1['six'],hue=df1['season'].max)
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.lineplot(df1['player'],df1['four'],hue=df1['season'].max)
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df34 = df.groupby('player')['strike_rate'].max()

# %%
plt.figure(figsize=(12,7))
sns.scatterplot(df1['player'],df1['strike_rate'],hue=df1['season'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.lineplot(df1['player'],df1['strike_rate'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,7))
sns.lineplot(df1['player'],df1['half_century'])
plt.show()
# Out:
# C:\Users\ssvr\Downloads\h\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize =(5,5))
sns.barplot(x=df['season'],y=df['half_century'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='half_century'>

# %%
sns.bplot(x=df['season'],y=df['century'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='century'>

# %%
plt.figure(figsize =(5,5))
sns.barplot(x=df['season'],y=df['half_century'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='half_century'>

# %%
plt.figure(figsize =(5,5))
sns.barplot(x=df['season'],y=df['century'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='century'>

# %%
plt.figure(figsize =(5,5))
sns.violinplot(x=df['season'],y=df['century'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='century'>

# %%
plt.figure(figsize =(5,5))
sns.violinplot(x=df['season'],y=df['strike_rate'])
# Out:
# <AxesSubplot:xlabel='season', ylabel='strike_rate'>

# %%
df['player'].value_counts()
# Out:
# Rohit Sharma       9
# Robin Uthappa      9
# MS Dhoni           9
# Dinesh Karthik     9
# Virat Kohli        8
#                   ..
# Hanuma Vihari      1
# Thisara Perera     1
# Kevin Pietersen    1
# Aditya Tare        1
# Pat Cummins        1
# Name: player, Length: 106, dtype: int64

# %%
df
# Out:
#                player  matches  inns  not_out  runs  high_score    avg  \
# 0         Chris Gayle       15    14        2   733         128  61.08
# 1      Gautam Gambhir       17    17        2   590          93  39.33
# 2      Shikhar Dhawan       15    15        1   569          84  40.64
# 3      Ajinkya Rahane       16    16        2   560         103  40.00
# 4     Virender Sehwag       16    16        1   495          87  33.00
# ...               ...      ...   ...      ...   ...         ...    ...
# 1163  Shimron Hetmyer       12    11        3   185          45  23.12
# 1164   Dinesh Karthik       14    14        2   169          58  14.08
# 1165      Pat Cummins       14    11        4   146          53  20.85
# 1176    Krunal Pandya       16    12        6   109          34  18.16
# 1177    Glenn Maxwell       13    11        4   108          32  15.42
#
#       balls_faced  strike_rate  century  half_century  four  six  season
# ...
